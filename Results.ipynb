# %% [markdown]
# # Таблица результатов

# %%
data.style.set_properties(pd.IndexSlice[14:, :], **{"font-weight": "bold"})
# Out:
# <style  type="text/css" >
#     #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col0 {
#             font-weight:  bold;
#         }    #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col1 {
#             font-weight:  bold;
#         }    #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col2 {
#             font-weight:  bold;
#         }    #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col3 {
#             font-weight:  bold;
#         }    #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col4 {
#             font-weight:  bold;
#         }    #T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20frow14_col5 {
#             font-weight:  bold;
#         }</style>
# <table id="T_03b92d58_53bc_11e8_ab4a_50b7c3d7e20f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ФИО</th>
#         <th class="col_heading level0 col1" >Контест 1</th>
#         <th class="col_heading level0 col2" >Тест</th>
#         <th class="col_heading level0 col3" >К/р 1</th>
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("results.csv", header=0)
