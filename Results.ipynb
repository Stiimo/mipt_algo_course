# %% [markdown]
# # Таблица результатов

# %%
data
# Out:
#                                ФИО  Контест 1  Контест 2  К/р 1  Пересдача  \
# 0      Агошков Вячеслав Евгеньевич        997       1192    755          0
# 1         Ашитков Андрей Тарасович       1000       1489   1990        250
# 2       Бруттан Мария Вячеславовна       1000       1200    994       1250
# 3            Дабижа Мирон Олегович        998       1188   1346        250
# 4                  Зайченока Мария        998       1481    983        600
# 5        Коряжкина Анна Максимовна       1000       1495   2241          0
# 6           Купреев Павел Павлович       1000       1195   1046        560
# 7           Меликов Роман Октаевич       1000       1195    800        800
# 8    Прокопчук Иван Константинович        999        996    740        180
# 9   Проценко Людмила Александровна        899       1187    788       1000
# 10                Тимченко Алексей        998       1196    994        250
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("results.csv", header=0)

# %%
data["Итого"] = data.drop("ФИО", axis=1).sum(1).astype("int")
