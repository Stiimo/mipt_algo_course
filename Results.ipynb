# %% [markdown]
# # Таблица результатов

# %%
data.style.set_properties(pd.IndexSlice[17:, :], **{"font-weight": "bold"})
# Out:
# <style  type="text/css" >
#     #T_693ffd02_f568_11e8_aaaa_50b7c3d7e20frow17_col0 {
#             font-weight:  bold;
#         }    #T_693ffd02_f568_11e8_aaaa_50b7c3d7e20frow17_col1 {
#             font-weight:  bold;
#         }    #T_693ffd02_f568_11e8_aaaa_50b7c3d7e20frow17_col2 {
#             font-weight:  bold;
#         }    #T_693ffd02_f568_11e8_aaaa_50b7c3d7e20frow17_col3 {
#             font-weight:  bold;
#         }</style>
# <table id="T_693ffd02_f568_11e8_aaaa_50b7c3d7e20f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >ФИО</th>
#         <th class="col_heading level0 col1" >Кр1</th>
#         <th class="col_heading level0 col2" >Сортировки</th>
#         <th class="col_heading level0 col3" >Рекурсия</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_693ffd02_f568_11e8_aaaa_50b7c3d7e20flevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("results.csv", header=0)
